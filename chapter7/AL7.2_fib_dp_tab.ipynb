# %% [markdown]
# # 1.문제 정의
# 문제이름 : 피보나치수열(테이블화 이용)
# 문제설명 : 테이블화를 이용하여 피보나치수열을 구한다.
# 문제예시 : 테이블화를 이용하여 fib(8)을 구한다.
# # 2.알고리즘 설명
# 1. n + 1크기의 테이블을 만들고 None으로 초기화한다.
# 2. 기반상황(fib[0]=0, fib[1]=1)의 값을 저장한다.
# 3. 상향식으로 i=2부터 증가하며 값을 테이블에 저장한다.
# 4. 구하려는 fib[n]의 값을 리턴한다.
# # 3.손으로 푼 예제
# ![AL7.2.jpg](attachment:AL7.2.jpg)
# # 4.알고리즘 개요
# 명칭 : 피보나치수열(테이블화 이용)
# 입력변수 : 테이블화를 이용하여 피보나치수열로 값을 구할 n
# 출력 : 테이블화를 이용하여 피보나치수열의 값을 구한 fib[n]
# # 5.알고리즘 코드

# %%
def fib_dp_tab(n) :
    f = [None] * (n+1)
    f[0] = 0
    f[1] = 1
    for i in range(2, n + 1):
        f[i] = f[i-1] + f[i-2]
    return f[n]

# %% [markdown]
# # 6.테스트 코드

# %%
def fib_dp_tab(n) :
    f = [None] * (n+1)
    f[0] = 0
    f[1] = 1
    for i in range(2, n + 1):
        f[i] = f[i-1] + f[i-2]
    return f[n]

n = 8
print(f"테이블화를 이용한 피보나치수열{n}의 값 : {fib_dp_tab(n)}")
# Out:
# 테이블화를 이용한 피보나치수열8의 값 : 21

# %% [markdown]
# # 7.수행 결과
# ![image.png](attachment:image.png)
# # 8.복잡도 분석
# 테이블화를 이용하여 피보나치수열을 구하려면 기반상황부터 구하려는 n까지 테이블을 채워야하므로 시간복잡도는
# $$O(n)이다.

# %% [markdown]
# # 9.작성자
# AL7.2 작성자 : 202110501 박건호
